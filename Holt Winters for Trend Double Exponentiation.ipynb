# %% [markdown]
# SES does not take into consideration the trend and seasonality effects, Hence we move forward to Holt Winter approach

# %% [markdown]
# Level  = alpha
# Trend  = beta
# Seasonality = gamma

# %%
library(tsdl)

# %%
for(i in 1:648){
    print(paste(i," ",attributes(tsdl[[i]])))
}
# Out:
# [1] "1   c(1948, 1979.75, 4)"
# [2] "1   ts"
# [3] "1   Abraham & Ledolter (1983)"
# [4] "1   Quarterly Iowa nonfarm income (1948 <U+FFFD> 1979)"
# [5] "1   Macroeconomic"
# [1] "2   c(1972, 1979.75, 12)"
# [2] "2   ts"
# [3] "2   Abraham & Ledolter (1983)"
# [4] "2   Monthly demand repair parts large/heavy equip. Iowa 1972 <U+FFFD> 1979"
# [5] "2   Industry"
# [1] "3   c(1971, 1979.75, 12)"
# [2] "3   ts"
# [3] "3   Abraham & Ledolter (1983)"
# [4] "3   Montly av. residential gas usage Iowa (cubic feet)*100 <U+FFFD>71 <U+FFFD> <U+FFFD>79"
# [5] "3   Utilities"
# [1] "4   c(1960, 1975.91666666667, 12)"
# [2] "4   ts"
# [3] "4   Abraham & Ledolter (1983)"
# [4] "4   Monthly gasoline demand Ontario gallon millions 1960 <U+FFFD> 1975"
# [5] "4   Sales"
# [1] "5   c(1967, 1975.58333333333, 12)"
# [2] "5   ts"
# [3] "5   Abraham & Ledolter (1983)"
# [4] "5   Monthly % changes in Canadian wages and salaries <U+FFFD>67 <U+FFFD> <U+FFFD>75"
# [5] "5   Macroeconomic"
# ...

# %%
money.data.ts = ts(tsdl[[141]])
plot(money.data.ts, main="Time Plot of Volume of Money")
acf(money.data.ts, main="ACF of Volume of Money", na.action = na.pass)
acf(money.data.ts, type="partial", main="PACF of Volume of Money", na.action = na.pass)
# Out:
# Plot with title "Time Plot of Volume of Money"
# Plot with title "ACF of Volume of Money"
# Plot with title "PACF of Volume of Money"
