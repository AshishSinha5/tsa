# %%
install.packages("fma")
library(fma)
# Out:
# package 'fma' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\ashish\AppData\Local\Temp\Rtmp84W7vM\downloaded_packages
# Loading required package: forecast
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# Registered S3 methods overwritten by 'forecast':
#   method             from
#   fitted.fracdiff    fracdiff
#   residuals.fracdiff fracdiff

# %%
print(milk)
# Out:
#    Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# 1  589 561 640 656 727 697 640 599 568 577 553 582
# 2  600 566 653 673 742 716 660 617 583 587 565 598
# 3  628 618 688 705 770 736 678 639 604 611 594 634
# 4  658 622 709 722 782 756 702 653 615 621 602 635
# 5  677 635 736 755 811 798 735 697 661 667 645 688
# 6  713 667 762 784 837 817 767 722 681 687 660 698
# 7  717 696 775 796 858 826 783 740 701 706 677 711
# 8  734 690 785 805 871 845 801 764 725 723 690 734
# 9  750 707 807 824 886 859 819 783 740 747 711 751
# 10 804 756 860 878 942 913 869 834 790 800 763 800
# 11 826 799 890 900 961 935 894 855 809 810 766 805
# 12 821 773 883 898 957 924 881 837 784 791 760 802
# 13 828 778 889 902 969 947 908 867 815 812 773 813
# 14 834 782 892 903 966 937 896 858 817 827 797 843

# %%
par(mfrow = c(2,1))
plot(milk, main = "Monthly milk production per cow")
plot(milk[0:24], type = "l")
# Out:
# Plot with title "Monthly milk production per cow"

# %% [markdown]
# Trend Going up and their is seasonality going up

# %%
# difference = 1
# seasonal diffrence  = 1
# seaseonal span = 12
# diffrencing accordingly we get stationary ts
data = diff(diff(milk),12)
plot(data)
# Out:
# plot without title

# %%
par(mfrow = c(2,1))
acf(data, lag.max = 50)
acf(data, lag.max = 50, type = "partial")
# Out:
# Plot with title "Series  data"

# %%
ACF
