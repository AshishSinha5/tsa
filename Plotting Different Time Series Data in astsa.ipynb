# %%
#Loading Dataset
install.packages('astsa', repos='http://cran.us.r-project.org')
# Out:
#   There is a binary version available but the source version is later:
#       binary source needs_compilation
# astsa    1.8    1.9             FALSE
# installing the source package 'astsa'

# %%
require(astsa)
# Out:
# Loading required package: astsa

# %%
#Desription of the dataset
help(astsa)

# %% [markdown]
# *Includes data and scripts to accompany Time Series Analysis and Its Applications: With R Examples (4th ed) by R.H. Shumway and D.S. Stoffer. Springer Texts in Statistics, 2017. Softcover ISBN: 978-3319524511; eBook ISBN 978-3319524528; DOI: 10.1007/978-3319524528, and Time Series: A Data Analysis Approach Using R, Chapman-Hall, 2019. ISBN: 978-0367221096.*

# %%
help(jj)

# %% [markdown]
# Johnson and Johnson quarterly earnings per share, 84 quarters (21 years) measured from the first quarter of 1960 to the last quarter of 1980.

# %%
plot(jj,type = "o", main = "Johnson and Johnson quarterly earnings per share", xlab = "years", ylab = "Earning")
# Out:
# Plot with title "Johnson and Johnson quarterly earnings per share"

# %%
help(flu)

# %% [markdown]
# Monthly pneumonia and influenza deaths per 10,000 people in the United States for 11 years, 1968 to 1978.

# %%
plot(flu, main = "Monthly pneumonia and influenza deaths", ylab = "No. of people per 10000", xlab = "Years" )
# Out:
# Plot with title "Monthly pneumonia and influenza deaths"

# %%
help(globtemp)

# %% [markdown]
# Global mean land-ocean temperature deviations (from 1951-1980 average), measured in degrees centigrade, for the years 1880-2015.

# %%
plot(globtemp , main = "Global mean land-ocean temperature deviations" , ylab = "Deviation in Temprature", xlab = "Years", type = "o")
# Out:
# Plot with title "Global mean land-ocean temperature deviations"

# %%
help(globtempl)

# %% [markdown]
# Global mean [land only] temperature deviations (from 1951-1980 average), measured in degrees centigrade, for the years 1880-2015.

# %%
plot(globtempl, main = "Global mean [land only] temperature deviations", xlab = "Years", ylab = "Temprature Daviations", type = "o")
# Out:
# Plot with title "Global mean [land only] temperature deviations"
