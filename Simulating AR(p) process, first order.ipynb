# %%
#AR(1) process
#Xt = Zt + phi*X(t-1)
set.seed(2016); N = 1000; phi = 0.4
Z = rnorm(N,0,1); X = NULL; X[1] = Z[1];

for(t in 2:N){
    X[t] = Z[t] + phi*X[t-1]
}
X.ts = ts(X)
par(mfrow = c(2,1))
plot(X.ts,main="AR(1) Time Series on White Noise, phi=.4")
X.acf = acf(X.ts,main="AR(1) Time Series on White Noise, phi=.4")
# Out:
# Plot with title "AR(1) Time Series on White Noise, phi=.4"

# %% [markdown]
# First two of the three lag spacing have a significant value

# %% [markdown]
# If we change the value phi to 1
# We will get a simple random walk

# %%
#AR(1) process with phi = 1
#Xt = Zt + phi*X(t-1)
set.seed(2016); N = 1000; phi = 1
Z = rnorm(N,0,1); X = NULL; X[1] = Z[1];

for(t in 2:N){
    X[t] = Z[t] + phi*X[t-1]
}
X.ts = ts(X)
par(mfrow = c(2,1))
plot(X.ts,main="AR(1) Time Series on White Noise, phi=1")
X.acf = acf(X.ts,main="AR(1) Time Series on White Noise, phi=1")
# Out:
# Plot with title "AR(1) Time Series on White Noise, phi=1"

# %%
# Simulating AR(2) process:
# Xt = Zt + 0.7X(t-1) + 0.3X(t-2)
#set.seed(2017)
X.ts <-arima.sim(list(ar = c(.7, .2)), n=1000)
par(mfrow=c(2,1))
plot(X.ts,main="AR(2) Time Series, phi1=.7, phi2=.2")
X.acf = acf(X.ts, main="Autocorrelation of AR(2) Time Series")
# Out:
# Plot with title "Autocorrelation of AR(2) Time Series"

# %%
phi1 = .5; phi2 = -.4; 
X.ts <-arima.sim(list(ar = c(phi1 , phi2)), n=1000)
par(mfrow=c(2,1))
plot(X.ts,main=paste("AR(2) Time Series, phi1=",phi1, "phi2=", phi2))
X.acf = acf(X.ts, main="Autocorrelation of AR(2) Time Series")
# Out:
# Plot with title "Autocorrelation of AR(2) Time Series"
